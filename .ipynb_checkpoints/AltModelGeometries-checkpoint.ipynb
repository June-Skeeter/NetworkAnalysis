# %%
from pandas import read_csv, DataFrame
from numpy.random import seed
from sklearn.preprocessing import scale
from keras.models import Sequential
from keras.constraints import maxnorm
from keras.optimizers import SGD
from keras.layers import Dense, Merge
from keras.layers.normalization import BatchNormalization
from keras import initializers, layers
import ReadStandardTimeFill as RSTF
import matplotlib.pyplot as plt
from sklearn import metrics
import os

# %%
seed(13)

def Footprint(Input,N):
    model = Sequential()
    model.add(Dense(N, input_shape = (Input.shape[1],), activation = 'relu'))
    model.add(BatchNormalization())
    return(model)
    
def Weather(Input,N):
    model = Sequential()
    model.add(Dense(N, input_shape = (Input.shape[1],), activation = 'relu'))
    model.add(BatchNormalization())
    return(model)
    
def Concat(Inputs,N):
    model = Sequential()
    model.add(Merge(Inputs, mode = 'concat'))
    model.add(Dense(N, activation = 'relu',kernel_initializer=initializer))
#     model.add(Dense(2))
    return(model)
    
def Compile(model):
    model.add(Dense(1))
    callbacks = [EarlyStopping(monitor='val_loss', patience=2)]
    model.compile(loss='mean_squared_error', optimizer='adam')
    return(model,callbacks)

# %%
cwd = os.getcwd()
params={}
params['Dpath'] = cwd+'/Illisarvik/'
RST = RSTF.ReadStandardTimeFill(params['Dpath']+'ECData.csv')
df = RST.Master[['fch4','H','wind_speed','VWC','VPD','air_pressure',
                 'Sedge','Sparse',"Grass",'Water',"Shrub","Out_of_Basin"]].dropna()
Y = scale(df['fch4'])
df["AllElse"]=df[["Sparse","Grass","Shrub",'Water',"Out_of_Basin"]].sum(axis=1)
# print(df["AllElse"])
X1 = scale(df[["Sedge","Sparse","Grass","Shrub",'Water',"Out_of_Basin"]])
X2 = scale(df[["H", "VWC",'wind_speed','VPD']])
Fp = Footprint(X1,N=X1.shape[1]*2)
Wt = Weather(X2,N=X2.shape[1]*2)
FullModel = Concat([Fp,Wt],N=X1.shape[1]*2+X2.shape[1]*2)
FullModel = Compile(FullModel)
FullModel.fit([X1, X2], Y, batch_size = 100, nb_epoch = 200, verbose = 0)
Yp = FullModel.predict([X_train,y_train],
                       batch_size=100,
                      callbacks=callbacks,
                      validation_data=(X_test, y_test))
score = FullModel.evaluate([X1,X2], Y, batch_size=100)
print()
print('Score')
print(score)
print(metrics.r2_score(Y,Yp))


plt.figure(figsize=(10,10))
plt.scatter(Y,Yp,c='black',s=10,label = 'Concated')
plt.show()

plt.figure(figsize=(10,10))
plt.scatter(df['Sedge'],Yp,c='black',s=10,label = 'Concated')
plt.show()
# branch1 = Sequential()
# branch1.add(Dense(X1.shape[1]*2, input_shape = (X1.shape[1],), activation = 'relu',kernel_initializer=initializer))
# branch1.add(BatchNormalization())
# Out:
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:17: UserWarning: The `Merge` layer is deprecated and will be removed after 08/2017. Use instead layers from `keras.layers.merge`, e.g. `add`, `concatenate`, etc.
# C:\Anaconda3\lib\site-packages\keras\models.py:844: UserWarning: The `nb_epoch` argument in `fit` has been renamed `epochs`.
#   warnings.warn('The `nb_epoch` argument in `fit` '
# 100/789 [==>...........................] - ETA: 5s
# Score
# 0.20294008894583873
# 0.7970599166232497

# %% [markdown]
# Yp = model.predict([X1,X2],batch_size=100)
# score = model.evaluate([X1,X2], Y, batch_size=100)
# print()
# print('Score')
# print(score)
# print(metrics.r2_score(Y,Yp))
# plt.figure(figsize=(10,10))
# plt.scatter(Y,Yp,edgecolor='grey',marker='o',s=10,label = 'Concated')
#
# branch1.add(Dense(1))
# branch1.compile(loss='mean_squared_error', optimizer='adam')
# seed(2017)
# branch1.fit(X1, Y, batch_size = 100, nb_epoch = 200, verbose = 0)
# Yp = branch1.predict(X1,batch_size=100)
# score = branch1.evaluate(X1, Y, batch_size=100)
# print()
# print('Score')
# print(score)
# print(metrics.r2_score(Y,Yp))
# plt.scatter(Y,Yp,edgecolor='green',marker='o',s=10,label = 'Footprint')
#
# branch2.add(Dense(1))
# branch2.compile(loss='mean_squared_error', optimizer='adam')
# seed(2017)
# branch2.fit(X2, Y, batch_size = 100, nb_epoch = 200, verbose = 0)
# Yp = branch2.predict(X2,batch_size=100)
# score = branch2.evaluate(X2, Y, batch_size=100)
# print()
# print('Score')
# print(score)
# print(metrics.r2_score(Y,Yp))
# plt.scatter(Y,Yp,edgecolor='orange',marker='o',s=10,label = 'Weather')
#
# plt.xlabel('Observed')
# plt.ylabel('Modeled')
# plt.legend()
# plt.show()
